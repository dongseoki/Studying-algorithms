# %%
test = 437674

# %%
str(test)
# Out:
# '437674'

# %%
print(int(str(test),3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-e31415bce51f> in <module>
# ----> 1 print(int(str(test),3))
#
# ValueError: invalid literal for int() with base 3: '437674'

# %%
print(int('435',3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-2814fff4b227> in <module>
# ----> 1 print(int('435',3))
#
# ValueError: invalid literal for int() with base 3: '435'

# %%
def JinSuConvert(n, k):
    test = ''

    while n > 0:
        temp = n
        n = temp//k
        res = temp%k

        test = str(res) + test

    return test
#     return test 
    # 역순인 진수를 뒤집어 줘야 원래 변환 하고자하는 base가 출력
    
print(JinSuConvert(45, 3))
# Out:
# 1200

# %%
n = 437674
k = 3

# %%
converted_n = JinSuConvert(n,k)
itemList = converted_n.split('0')
print(itemList)
# Out:
# ['211', '2', '1', '1', '11']

# %%
def solution(n, q):
    rev_base = ''

    while n > 0:
        n, mod = divmod(n, q)
        rev_base += str(mod)
        print(n, mod, rev_base)
    print(rev_base)
    return rev_base[::-1] 
    # 역순인 진수를 뒤집어 줘야 원래 변환 하고자하는 base가 출력
    
print(solution(45, 3))
# Out:
# 15 0 0
# 5 0 00
# 1 2 002
# 0 1 0021
# 0021
# 1200

# %%
15%3
# Out:
# 0

# %%
eratosthenes_che_list = [True] * n
def makeEratosthenes_che(n):
    # 에라토스테네스의 체 초기화: n개 요소에 True 설정(소수로 간주)
    eratosthenes_che_list = [True] * n
# n의 최대 약수가 sqrt(n) 이하이므로 i=sqrt(n)까지 검사
    m = int(math.sqrt(n))
    for i in range(2, m + 1):
        if eratosthenes_che_list[i] == True:           # i가 소수인 경우
            for j in range(i+i, n, i): # i이후 i의 배수들을 False 판정
                eratosthenes_che_list[j] = False
 # 소수 목록 산출
    return eratosthenes_che_list
#     return [i for i in range(2, n) if sieve[i] == True]

# %%
prime_list(20)
# Out:
# [True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True]

# %%
import math

# %%
int(math.sqrt(40))
# Out:
# 6

# %%
eratosthenes_che_list = [True] * n
def makeEratosthenes_che(n):
    # 에라토스테네스의 체 초기화: n개 요소에 True 설정(소수로 간주)
#     eratosthenes_che_list = [True] * n
# n의 최대 약수가 sqrt(n) 이하이므로 i=sqrt(n)까지 검사
    eratosthenes_che_list[1] = False
    end = int(math.sqrt(n))
    for i in range(2, end + 1):
        if eratosthenes_che_list[i]:           # i가 소수인 경우
            for num in range(i*2, n, i): # i이후 i의 배수들을 False 판정
                eratosthenes_che_list[num] = False
 # 소수 목록 산출
#     return eratosthenes_che_list
#     return [i for i in range(2, n) if sieve[i] == True]

# %%
makeEratosthenes_che(437674)

# %%
eratosthenes_che_list[2]
# Out:
# True

# %%
eratosthenes_che_list
# Out:
# [True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
# ...

# %%
answer = 0
for testNum in itemList:
    if eratosthenes_che_list[int(testNum)]:
        answer +=1
    print(testNum, eratosthenes_che_list[int(testNum)], answer)
# Out:
# 211 True 1
# 2 True 2
# 1 False 2
# 1 False 2
# 11 True 3

# %%
answer
# Out:
# 3
